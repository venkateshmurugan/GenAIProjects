# %%
import os

#print(os.getenv('HF_TOKEN'))

# %%
pip install --upgrade smolagents
# Out:
# ...
#   Attempting uninstall: smolagents
#     Found existing installation: smolagents 1.17.0
#     Uninstalling smolagents-1.17.0:
#       Successfully uninstalled smolagents-1.17.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from smolagents import Tool

# %%
image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

x = image_generation_tool("A sunny beach")
# Out:
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔
# Since `api_name` was not defined, it was automatically set to the first available API: `/infer`.
# ---------------------------------------------------------------------------
# QueueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       1 image_generation_tool = Tool.from_space(
#       2     "black-forest-labs/FLUX.1-schnell",
#       3     name="image_generator",
#       4     description="Generate an image from a prompt"
#       5 )
# ----> 7 x = image_generation_tool("A sunny beach")
#
# File D:\anaconda3\Lib\site-packages\smolagents\tools.py:206, in Tool.__call__(self, sanitize_inputs_outputs, *args, **kwargs)
#     204 if sanitize_inputs_outputs:
#     205     args, kwargs = handle_agent_input_types(*args, **kwargs)
# --> 206 outputs = self.forward(*args, **kwargs)
#     207 if sanitize_inputs_outputs:
# ...

# %%
pip install --upgrade gradio_client
# Out:
# ...
#   Attempting uninstall: gradio_client
#     Found existing installation: gradio_client 1.10.2
#     Uninstalling gradio_client-1.10.2:
#       Successfully uninstalled gradio_client-1.10.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib.request import urlretrieve

from PIL import Image

background = Image.open(x)

background
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 from urllib.request import urlretrieve
#       3 from PIL import Image
# ----> 5 background = Image.open(x)
#       7 background
#
# NameError: name 'x' is not defined

# %%
from smolagents import CodeAgent, HfApiModel

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(tools=[image_generation_tool], model=model)
ff = agent.run("'Improve this Prompt, then generate an image of it', prompt='A rabbit wearing a space suit'")

ff
# Out:
# D:\anaconda3\Lib\site-packages\smolagents\models.py:1372: FutureWarning: HfApiModel was renamed to InferenceClientModel in version 1.14.0 and will be removed in 1.17.0.
#   if delta.tool_calls:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 'Improve this Prompt, then generate an image of it', prompt='A rabbit wearing a space suit'                     │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
background = Image.open(ff)
background
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 background = Image.open(ff)
#       2 background
#
# File D:\anaconda3\Lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: "C:\\Users\\Nesha Kumar\\GenAIProjects\\A fluffy white rabbit wearing a shiny silver space suit with gold accents, standing on a red Martian landscape with a view of the planet's rocky surface and thin atmosphere. The rabbit is looking curiously around, with a small oxygen tank attached to its suit."

# %%
from smolagents import Tool

image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

from smolagents import CodeAgent, HfApiModel

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(tools=[image_generation_tool], model=model)

generated_image = agent.run("'Improve this prompt and then generate an image of it', prompt=' A girl with wings'")

from urllib.request import urlretrieve

from PIL import Image

img_obj = Image.open(generated_image)

img_obj
# Out:
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔
# Since `api_name` was not defined, it was automatically set to the first available API: `/infer`.
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 'Improve this prompt and then generate an image of it', prompt=' A girl with wings'                             │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
# ...
